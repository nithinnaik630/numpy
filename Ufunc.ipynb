# %%
# noraml iteration

# %%
x =[20, 30 , 38,20]
y= [30, 27, 39, 10]
z = []
for i, j in zip(x, y):
    z.append(i+j)
print(z)
# Out:
# [50, 57, 77, 30]

# %%
# Ufunc format

# %%
import numpy as np
x = [19,10,12,29]
y = [29,38,49,34]

z = np.add(x,y)

print(z)
# Out:
# [48 48 61 63]

# %%
# creating a function

# %%
import numpy as np 

def myadd(x, y):
   return x+y

myadd = np.frompyfunc(myadd, 2, 1)

print(myadd([1, 2, 3, 4], [5, 6, 7, 8]))
# Out:
# [6 8 10 12]

# %%
import numpy as np
print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
import numpy as np
print(type(np.concatenate))
# Out:
# <class 'numpy._ArrayFunctionDispatcher'>

# %%
import numpy as np
if type(np.add) == np.ufunc:
    print("it ufunc")
else:
    print("it not a ufunc")
# Out:
# it ufunc

# %%
# Simple arithmetic operation

# %%
# Addition

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.add(myarr1, myarr2)

print(newarr)
# Out:
# [35 66 60 58]

# %%
import numpy as np
a = np.array([27, 23, 28])
b = np.add(a, 1)
print(a)
# Out:
# [27 23 28]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.add(A, B))
# Out:
# [[10 12 14 16]
#  [14 16 18 20]]

# %%
import numpy as np 
a = np.array([23,33, 43],dtype=np.int8)
b = np.array([2,3, 1],dtype=np.int32)
print(np.add(a, b))
# Out:
# [25 36 44]

# %%
import numpy as np 
a = np.array([23,33, 43],dtype=np.int32)
b = np.array([2,3, 1],dtype=np.int32)
print(np.add(a, b))
# Out:
# [25 36 44]

# %%
# Subtraction method

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.subtract(myarr1, myarr2)

print(newarr)
# Out:
# [-11  10  20  -2]

# %%
import numpy as np 

a = np.array([23,33, 43],dtype=np.int8)
b = np.array([2,3, 1],dtype=np.int32)

print(np.subtract(a, b))
# Out:
# [21 30 42]

# %%
import numpy as np 

a = np.array([23,33, 43],dtype=np.int32)
b = np.array([2,3, 1],dtype=np.int32)

print(np.subtract(a, b))
# Out:
# [21 30 42]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.subtract(B, A))
# Out:
# [[8 8 8 8]
#  [4 4 4 4]]

# %%
# Multiplication method

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.multiply(myarr1, myarr2)

print(newarr)
# Out:
# [ 276 1064  800  840]

# %%
import numpy as np 

a = np.array([23,33, 43],dtype=np.int8)
b = np.array([2,3, 1],dtype=np.int32)

print(np.multiply(a, b))
# Out:
# [46 99 43]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.multiply(B, A))
# Out:
# [[ 9 20 33 48]
#  [45 60 77 96]]

# %%
# Divison method

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.divide(myarr1, myarr2)

print(newarr)
# Out:
# [0.52173913 1.35714286 2.         0.93333333]

# %%
import numpy as np 

a = np.array([23,33, 43],dtype=np.int8)
b = np.array([2,3, 1],dtype=np.int32)

print(np.divide(a, b))
# Out:
# [11.5 11.  43. ]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.divide(B, A))
# Out:
# [[9.         5.         3.66666667 3.        ]
#  [1.8        1.66666667 1.57142857 1.5       ]]

# %%
# Power method

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.power(myarr1, myarr2)

print(newarr)
# Out:
# [-5038753926841630720   333500598735339520  1152921504606846976
#   1152921504606846976]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.power(B, A))
# Out:
# [[        9       100      1331     20736]
#  [    59049   1000000  19487171 429981696]]

# %%
# Remainder method

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.remainder(myarr1, myarr2)

print(newarr)
# Out:
# [12 10  0 28]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.remainder(B, A))
# Out:
# [[0 0 2 0]
#  [4 4 4 4]]

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.mod(B, A))
# Out:
# [[0 0 2 0]
#  [4 4 4 4]]

# %%
# Quotient and mod

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]
myarr2 = [ 23, 28, 20, 30]

newarr = np.divmod(myarr1, myarr2)

print(newarr)
# Out:
# (array([0, 1, 2, 0]), array([12, 10,  0, 28]))

# %%
import numpy as np

A = np.array([[1, 2, 3, 4],
             [5, 6, 7, 8]])
B = np.array([9, 10, 11, 12])

print(np.divmod(B, A))
# Out:
# (array([[9, 5, 3, 3],
#        [1, 1, 1, 1]]), array([[0, 0, 2, 0],
#        [4, 4, 4, 4]]))

# %%
# Absolute

# %%
import numpy as np

myarr1 = [ 12, 38, 40, 28]

newarr = np.absolute(myarr1)

print(newarr)
# Out:
# [12 38 40 28]

# %%
import numpy as np

myarr1 = [ 12, -38, -40, 28]

newarr = np.absolute(myarr1)

print(newarr)
# Out:
# [12 38 40 28]
